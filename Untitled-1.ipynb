# %%
import numpy as np
import matplotlib.pyplot as plt
import retinaface
import os
import cv2

# %%
cats = cv2.imread("cat.jpg")
cats = cv2.cvtColor(cats, cv2.COLOR_BGR2RGB)
plt.imshow(cats)
plt.show()

# %%
blured_cat = cv2.GaussianBlur(cats, (51,51), -1)
plt.imshow(blured_cat)

# %%
Identity = np.array([[0, 0, 0],
                    [0, 1, 0],
                    [0, 0, 0]])


identity = cv2.filter2D(src=cats, ddepth=-1, kernel=Identity)

identity = cv2.

# %%
plt.imshow(Identity)
